# %%
import wbgapi as wb
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def read_data(code):
    worldbank_data = wb.data.DataFrame(code, ['BRA'], range(1990, 2020, 1))
    return worldbank_data

# %%
def show_corr(df):
    plt.figure(figsize=(16, 12))
    sns.heatmap(df, annot=True)
    plt.show()

# %% [markdown]
# ## Agriculture

# %%
agriculture = read_data(['NV.AGR.TOTL.CD','SL.AGR.EMPL.ZS','SP.RUR.TOTL.ZS','AG.PRD.FOOD.XD'])
# Out:
# /home/jonathan-oliveira/UNB/deeplearning/EconomIA/env/lib/python3.8/site-packages/wbgapi/data.py:327: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   dummy = pd.Series()    # empty series - never assigned actual values

# %%
agriculture.fillna(agriculture.mean(),inplace=True)

# %%
agriculture.loc[['SL.AGR.EMPL.ZS','SP.RUR.TOTL.ZS','AG.PRD.FOOD.XD']].sum()
# Out:
# YR1990    9.069316e+09
# YR1991    8.493000e+01
# YR1992    8.683600e+01
# YR1993    8.609900e+01
# YR1994    8.809700e+01
# YR1995    8.996000e+01
# YR1996    8.771800e+01
# YR1997    8.883200e+01
# YR1998    8.791900e+01
# YR1999    9.148400e+01
# YR2000    9.194800e+01
# YR2001    9.433700e+01
# YR2002    9.755000e+01
# YR2003    1.025870e+02
# YR2004    1.051790e+02
# YR2005    1.051260e+02
# YR2006    1.073570e+02
# YR2007    1.113320e+02
# YR2008    1.150510e+02
# YR2009    1.136260e+02
# YR2010    1.171650e+02
# YR2011    1.197590e+02
# YR2012    1.177270e+02
# YR2013    1.235810e+02
# YR2014    1.239680e+02
# YR2015    1.262300e+02
# YR2016    1.231780e+02
# YR2017    1.305710e+02
# YR2018    1.300310e+02
# YR2019    1.317660e+02
# dtype: float64

# %%
agriculture
# Out:
#                       YR1990        YR1991        YR1992        YR1993  \
# series
# AG.PRD.FOOD.XD  3.816000e+01  3.998000e+01  4.253000e+01  4.297000e+01
# NV.AGR.TOTL.CD  2.720795e+10  2.343895e+10  2.233677e+10  2.496349e+10
# SL.AGR.EMPL.ZS  9.069316e+09  1.964000e+01  1.975000e+01  1.931000e+01
# SP.RUR.TOTL.ZS  2.607800e+01  2.531000e+01  2.455600e+01  2.381900e+01
#
#                       YR1994        YR1995        YR1996        YR1997  \
# series
# AG.PRD.FOOD.XD  4.631000e+01  4.943000e+01  4.892000e+01  5.103000e+01
# NV.AGR.TOTL.CD  4.582270e+10  3.855642e+10  4.055183e+10  4.137864e+10
# SL.AGR.EMPL.ZS  1.869000e+01  1.814000e+01  1.710000e+01  1.685000e+01
# SP.RUR.TOTL.ZS  2.309700e+01  2.239000e+01  2.169800e+01  2.095200e+01
#
#                       YR1998        YR1999  ...        YR2010        YR2011  \
# series                                      ...
# AG.PRD.FOOD.XD  5.150000e+01  5.529000e+01  ...  8.884000e+01  9.240000e+01
# ...

# %%
corr_agriculture = agriculture.T.corr(method='pearson')

# %%
plt.figure(figsize=(16, 12))
sns.heatmap(corr_agriculture, annot=True)
plt.show()

# %% [markdown]
# ## Education

# %%
education = read_data(["SE.XPD.PRIM.ZS", "SE.XPD.SECO.ZS", "SE.XPD.TERT.ZS",'SE.SEC.CMPT.LO.ZS','SE.SEC.UNER.LO.ZS','SE.PRM.UNER.ZS',"SE.ADT.LITR.ZS","SE.ADT.1524.LT.ZS","SE.PRM.CMPT.ZS"])
# Out:
# /home/jonathan-oliveira/UNB/deeplearning/EconomIA/env/lib/python3.8/site-packages/wbgapi/data.py:327: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   dummy = pd.Series()    # empty series - never assigned actual values

# %%
education.fillna(education.mean(),inplace=True)

# %%
corr_education = education.T.corr(method='pearson')

# %%
show_corr(corr_education)

# %% [markdown]
# ## Health

# %%
health = read_data(['SH.XPD.CHEX.GD.ZS','SH.STA.BASS.ZS','SH.MED.BEDS.ZS','SH.MED.NUMW.P3','SH.MED.PHYS.ZS'])
# Out:
# /home/jonathan-oliveira/UNB/deeplearning/EconomIA/env/lib/python3.8/site-packages/wbgapi/data.py:327: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   dummy = pd.Series()    # empty series - never assigned actual values

# %%
health.fillna(health.mean(), inplace=True)

# %%
corr_health = health.T.corr(method='pearson')

# %%
show_corr(corr_health)

# %% [markdown]
# ## Science

# %%
science = read_data(['GB.XPD.RSDV.GD.ZS','IT.NET.SECR.P6','EP.PMP.SGAS.CD','IP.JRN.ARTC.SC','IP.IDS.NRCT','IP.IDS.RSCT'])
# Out:
# /home/jonathan-oliveira/UNB/deeplearning/EconomIA/env/lib/python3.8/site-packages/wbgapi/data.py:327: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   dummy = pd.Series()    # empty series - never assigned actual values

# %%
science.fillna(science.mean(), inplace=True)

# %%
corr_science = science.T.corr(method='pearson')

# %%
show_corr(corr_science)

# %% [markdown]
# ## Environment

# %%
environment = read_data(["EN.ATM.METH.AG.ZS","EN.ATM.NOXE.AG.ZS","EN.ATM.CO2E.GF.ZS", "EG.ELC.ACCS.ZS","EG.ELC.HYRO.ZS","EG.ELC.RNWX.ZS"])
# Out:
# /home/jonathan-oliveira/UNB/deeplearning/EconomIA/env/lib/python3.8/site-packages/wbgapi/data.py:327: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   dummy = pd.Series()    # empty series - never assigned actual values

# %%
corr_environment = environment.T.corr(method='pearson')

# %%
show_corr(corr_environment)

# %% [markdown]
# ## Development

# %%
development =  read_data(['SI.POV.GINI','SI.DST.50MD','SL.EMP.VULN.ZS','SL.UEM.TOTL.NE.ZS','SI.DST.50MD'])
# Out:
# /home/jonathan-oliveira/UNB/deeplearning/EconomIA/env/lib/python3.8/site-packages/wbgapi/data.py:327: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   dummy = pd.Series()    # empty series - never assigned actual values

# %%
corr_development = development.T.corr(method='pearson')

# %%
show_corr(corr_development)
