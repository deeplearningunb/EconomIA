# %%
import pandas as pd
import wbgapi as wb
import matplotlib.pyplot as plt

# %%
wb.source.info()
# Out:
# id    name                                                                  code      concepts  lastupdated
# ----  --------------------------------------------------------------------  ------  ----------  -------------
# 1     Doing Business                                                        DBS              3  2021-08-18
# 2     World Development Indicators                                          WDI              3  2022-04-27
# 3     Worldwide Governance Indicators                                       WGI              3  2021-09-27
# 5     Subnational Malnutrition Database                                     SNM              3  2016-03-21
# 6     International Debt Statistics                                         IDS              4  2022-01-14
# 11    Africa Development Indicators                                         ADI              3  2013-02-22
# 12    Education Statistics                                                  EDS              3  2020-12-20
# ...

# %%
wb.series.info(db=6)
# Out:
# id                   value
# -------------------  ---------------------------------------------------------------------------------------------------
# BM.GSR.TOTL.CD       Imports of goods, services and primary income (current US$)
# BN.CAB.XOKA.CD       Current account balance (current US$)
# BX.GRT.EXTA.CD.DT    Grants, excluding technical cooperation (current US$)
# BX.GRT.TECH.CD.DT    Technical cooperation grants (current US$)
# BX.GSR.TOTL.CD       Exports of goods, services and primary income (current US$)
# BX.KLT.DINV.CD.DT    Foreign direct investment, net inflows in reporting economy (DRS, current US$)
# BX.KLT.DREM.CD.DT    Primary income on FDI (current US$)
# BX.PEF.TOTL.CD.DT    Portfolio investment, equity (DRS, current US$)
# BX.TRF.PWKR.CD.DT    Personal transfers and compensation of employees, received (current US$)
# DT.AMT.BLAT.CB.CD    CB, bilateral (AMT, current US$)
# DT.AMT.BLAT.CD       PPG, bilateral (AMT, current US$)
# ...

# %%
americaLatina = wb.economy.metadata.get('LCA')
americaLatina
# Out:
# ...
# Country: LCA
#
# 2-alphacode: LC
# --------
# BalanceofPaymentsManualinuse: BPM6
# --------
# CurrencyUnit: East Caribbean dollar
# --------
# ExternaldebtReportingstatus: Actual
# --------
# GovernmentAccountingconcept: Budgetary central government
# --------
# IMFdatadisseminationstandard: Enhanced General Data Dissemination System (e-GDDS)
# --------
# IncomeGroup: Upper middle income
# --------
# Latestagriculturalcensus: 2007
# --------
# Latesthouseholdsurvey: Multiple Indicator Cluster Survey, 2012
# --------
# Latestindustrialdata: 1997
# --------
# Latestpopulationcensus: 2020 (expected)
# --------
# Latesttradedata: 2017
# --------
# Lendingcategory: Blend
# --------
# LongName: St. Lucia
# --------
# Nationalaccountsbaseyear: 2018
# --------
# PPPsurveyyear: 2017, 2011
# --------
# Region: Latin America & Caribbean
# --------
# ShortName: St. Lucia
# --------
# SNApricevaluation: Value added at basic prices (VAB)
# --------
# ...

# %%
unemployment = wb.data.DataFrame('SL.UEM.TOTL.NE.ZS',economy='BRA', time=range(2012,2022),labels=True, index='time')
unemployment = unemployment.reset_index()
unemployment = unemployment.drop(columns='time').rename(columns={'BRA':'Unemployment %'})
unemployment = unemployment.set_index('Time')
unemployment
# Out:
# /home/julia/.local/lib/python3.8/site-packages/wbgapi/data.py:327: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   dummy = pd.Series()    # empty series - never assigned actual values
#       Unemployment %
# Time
# 2021             NaN
# 2020           13.93
# 2019           12.05
# 2018           12.46
# 2017           12.93
# 2016           11.74
# 2015            8.56
# 2014            6.76
# 2013            7.07
# 2012            7.25
# 2011            6.92
# 2010             NaN
# 2009            8.52
# 2008            7.34
# 2007            8.33
# 2006            8.64
# 2005            9.57

# %%
unemployment = wb.data.DataFrame('SL.UEM.TOTL.NE.ZS',economy='COL', time=range(2012,2022),labels=True, index='time')
unemployment = unemployment.reset_index()
unemployment = unemployment.drop(columns='time').rename(columns={'COL':'Unemployment %'})
unemployment = unemployment.set_index('Time')
unemployment
# Out:
# /home/julia/.local/lib/python3.8/site-packages/wbgapi/data.py:327: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   dummy = pd.Series()    # empty series - never assigned actual values
#       Unemployment %
# Time
# 2021             NaN
# 2020           15.04
# 2019            9.96
# 2018            9.11
# 2017            8.87
# 2016            8.69
# 2015            8.30
# 2014            8.57
# 2013            9.05
# 2012            9.74
# 2011           10.11
# 2010           10.98
# 2009           11.32
# 2008           10.52
# 2007           10.25
# 2006             NaN
# 2005           11.87

# %%
unemployment = wb.data.DataFrame('SL.UEM.TOTL.NE.ZS',economy='ARG', time=range(2012,2022),labels=True, index='time')
unemployment = unemployment.reset_index()
unemployment = unemployment.drop(columns='time').rename(columns={'ARG':'Unemployment %'})
unemployment = unemployment.set_index('Time')
unemployment
# Out:
# /home/julia/.local/lib/python3.8/site-packages/wbgapi/data.py:327: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   dummy = pd.Series()    # empty series - never assigned actual values
#       Unemployment %
# Time
# 2021             NaN
# 2020           11.46
# 2019            9.84
# 2018            9.22
# 2017            8.35
# 2016             NaN
# 2015             NaN
# 2014            7.27
# 2013            7.10
# 2012            7.22
# 2011            7.18
# 2010            7.71
# 2009            8.65
# 2008            7.84
# 2007            8.47
# 2006           10.08
# 2005           11.51

# %%
unemployment = wb.data.DataFrame('SL.UEM.TOTL.NE.ZS',economy='PER', time=range(2012,2022),labels=True, index='time')
unemployment = unemployment.reset_index()
unemployment = unemployment.drop(columns='time').rename(columns={'PE':'Unemployment %'})
unemployment = unemployment.set_index('Time')
unemployment
# Out:
# /home/julia/.local/lib/python3.8/site-packages/wbgapi/data.py:327: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   dummy = pd.Series()    # empty series - never assigned actual values
#        PER
# Time
# 2021   NaN
# 2020  7.45
# 2019  3.38
# 2018  3.49
# 2017  3.69
# 2016  3.74
# 2015  3.27
# 2014  3.21
# 2013  3.57
# 2012  3.24
# 2011  3.48
# 2010  3.60
# 2009  3.96
# 2008  4.03
# 2007  4.08
# 2006  4.17
# 2005  4.87

# %%
unemployment = wb.data.DataFrame('SL.UEM.TOTL.NE.ZS',economy='BOL', time=range(2012,2022),labels=True, index='time')
unemployment = unemployment.reset_index()
unemployment = unemployment.drop(columns='time').rename(columns={'BOL':'Unemployment %'})
unemployment = unemployment.set_index('Time')
unemployment
# Out:
# /home/julia/.local/lib/python3.8/site-packages/wbgapi/data.py:327: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   dummy = pd.Series()    # empty series - never assigned actual values
#       Unemployment %
# Time
# 2021             NaN
# 2020            7.90
# 2019            3.82
# 2018            3.52
# 2017            3.65
# 2016            3.50
# 2015            3.11
# 2014            2.02
# 2013            2.44
# 2012            2.07
# 2011            2.25
# 2010             NaN
# 2009            2.97
# 2008            2.60
# 2007            5.18
# 2006            5.08
# 2005            5.45
